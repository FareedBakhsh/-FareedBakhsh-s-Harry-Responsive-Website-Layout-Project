# %% [markdown]
# <a href="https://colab.research.google.com/github/FareedBakhsh/-FareedBakhsh-s-Harry-Responsive-Website-Layout-Project/blob/main/PythonhellowWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Write the hellow world

print("Hello world")
# Out:
# Hello world

# %%
# prompt: Write "Fareed has been started the new job as Source hunting in New company of Ecommerce and Virtual Assistant

print("Fareed has been started the new job as Source hunting in New company of Ecommerce and Virtual Assistant")
# Out:
# Fareed has been started the new job as Source hunting in New company of Ecommerce and Virtual Assistant
